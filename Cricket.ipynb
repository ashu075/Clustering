# %% [markdown]
# ## K-Means Clustering

# %% [markdown]
# **Overview**<br>
# <a href="https://archive.ics.uci.edu/ml/datasets/online+retail">Online retail is a transnational data set</a> which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# The steps are broadly:
# 1. Read and understand the data
# 2. Clean the data
# 3. Prepare the data for modelling
# 4. Modelling
# 5. Final analysis and reco

# %% [markdown]
# # 1. Read and visualise the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
# read the dataset
retail_df = pd.read_csv("Cricket.csv", sep=",", encoding="ISO-8859-1", header=0)
retail_df.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0
# 0  21367  86.23   49  96  20
# 1  18048  78.86   25  93  15
# 2  17046  80.39   30  82  20
# 3  14725  91.20   28  68  34
# 4  16020  78.96   19  77  28

# %%
# basics of the df
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 13 columns):
# Player    79 non-null object
# Span      79 non-null object
# Mat       79 non-null int64
# Inns      79 non-null int64
# NO        79 non-null int64
# Runs      79 non-null int64
# HS        79 non-null object
# Ave       79 non-null float64
# BF        79 non-null int64
# SR        79 non-null float64
# 100       79 non-null int64
# 50        79 non-null int64
# 0         79 non-null int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 8.1+ KB

# %% [markdown]
# # 2. Clean the data

# %%
# missing values
round(100*(retail_df.isnull().sum())/len(retail_df), 2)
# Out:
# Player    0.0
# Span      0.0
# Mat       0.0
# Inns      0.0
# NO        0.0
# Runs      0.0
# HS        0.0
# Ave       0.0
# BF        0.0
# SR        0.0
# 100       0.0
# 50        0.0
# 0         0.0
# dtype: float64

# %% [markdown]
# # 3. Prepare the data for modelling

# %%
# 2. rescaling
rfm_df = retail_df[['SR', 'Ave']]

# instantiate
scaler = StandardScaler()

# fit_transform
rfm_df_scaled = scaler.fit_transform(rfm_df)
rfm_df_scaled.shape
# Out:
# (79, 2)

# %%
rfm_df_scaled = pd.DataFrame(rfm_df_scaled)
rfm_df_scaled.columns = ['SR', 'Ave']
rfm_df_scaled.head()
# Out:
#          SR       Ave
# 0  0.703152  1.072294
# 1 -0.044139  0.587725
# 2  0.110997  0.596226
# 3  1.207091 -1.047909
# 4 -0.034000 -0.876185

# %% [markdown]
# # 4. Modelling

# %%
# k-means with some arbitrary k
kmeans = KMeans(n_clusters=4, max_iter=50,random_state=100)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=50,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=100, tol=0.0001, verbose=0)

# %%
kmeans.labels_
# Out:
# array([3, 1, 1, 0, 2, 1, 1, 1, 1, 1, 0, 1, 0, 3, 2, 3, 2, 0, 1, 1, 0, 1,
#        2, 1, 0, 3, 2, 0, 2, 1, 2, 2, 1, 2, 3, 2, 2, 1, 3, 1, 2, 2, 3, 2,
#        2, 2, 1, 2, 2, 1, 0, 1, 2, 2, 2, 2, 1, 0, 2, 0, 2, 0, 1, 3, 3, 1,
#        1, 2, 1, 2, 1, 2, 2, 2, 1, 1, 2, 0, 2])

# %%
# help(KMeans)

# %% [markdown]
# ## Finding the Optimal Number of Clusters
#
# ### SSD

# %%
# elbow-curve/SSD
ssd = []
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]
for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(rfm_df_scaled)
    
    ssd.append(kmeans.inertia_)
    
# plot the SSDs for each n_clusters
# ssd
plt.plot(ssd)

# %% [markdown]
# ### Silhouette Analysis
#
# $$\text{silhouette score}=\frac{p-q}{max(p,q)}$$
#
# $p$ is the mean distance to the points in the nearest cluster that the data point is not a part of
#
# $q$ is the mean intra-cluster distance to all the points in its own cluster.
#
# * The value of the silhouette score range lies between -1 to 1.
#
# * A score closer to 1 indicates that the data point is very similar to other data points in the cluster,
#
# * A score closer to -1 indicates that the data point is not similar to the data points in its cluster.

# %%
# silhouette analysis
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(rfm_df_scaled)
    
    cluster_labels = kmeans.labels_
    
    # silhouette score
    silhouette_avg = silhouette_score(rfm_df_scaled, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.37632823237612395
# For n_clusters=3, the silhouette score is 0.37047300011047957
# For n_clusters=4, the silhouette score is 0.38853833179708763
# For n_clusters=5, the silhouette score is 0.36858208433621903
# For n_clusters=6, the silhouette score is 0.37717077216467404
# For n_clusters=7, the silhouette score is 0.38350937801498225
# For n_clusters=8, the silhouette score is 0.3829839638240535

# %%
# final model with k=3
kmeans = KMeans(n_clusters=3, max_iter=50)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=50,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.labels_
# Out:
# array([3, 1, 1, 0, 2, 1, 1, 1, 1, 1, 0, 1, 0, 3, 2, 3, 2, 0, 1, 1, 0, 1,
#        2, 1, 0, 3, 2, 0, 2, 1, 2, 2, 1, 2, 3, 2, 2, 1, 3, 1, 2, 2, 3, 2,
#        2, 2, 1, 2, 2, 1, 0, 1, 2, 2, 2, 2, 1, 0, 2, 0, 2, 0, 1, 3, 3, 1,
#        1, 2, 1, 2, 1, 2, 2, 2, 1, 1, 2, 0, 2])

# %%
# assign the label
retail_df['cluster_id'] = kmeans.labels_
# retail_df[retail_df['cluster_id']==3]
retail_df.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0  cluster_id
# 0  21367  86.23   49  96  20           3
# 1  18048  78.86   25  93  15           1
# 2  17046  80.39   30  82  20           1
# 3  14725  91.20   28  68  34           0
# 4  16020  78.96   19  77  28           2

# %%
retail_df[retail_df['cluster_id']==3]
# Out:
#                      Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0      SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 13    MS Dhoni (Asia/INDIA)  2004-2017  295   255  70   9496  183*  51.32
# 15  AB de Villiers (Afr/SA)  2005-2017  222   213  39   9319  162*  53.55
# 25          V Kohli (INDIA)  2008-2017  188   180  29   8146   183  53.94
# 34             HM Amla (SA)  2008-2017  156   153  10   7186   159  50.25
# 38           MG Bevan (AUS)  1994-2004  232   196  67   6912  108*  53.58
# 42        IVA Richards (WI)  1975-1991  187   167  24   6721  189*  47.00
# 63          MJ Guptill (NZ)  2009-2017  146   143  16   5500  237*  43.30
# 64         MEK Hussey (AUS)  2004-2012  185   157  44   5442  109*  48.15
#
#        BF      SR  100  50   0  cluster_id
# 0   21367   86.23   49  96  20           3
# 13  10706   88.69   10  64   8           3
# 15   9295  100.25   24  53   7           3
# 25   8952   90.99   27  43  11           3
# 34   8069   89.05   25  33   3           3
# 38   9320   74.16    6  46   5           3
# 42   7451   90.20   11  45   7           3
# 63   6269   87.73   12  32  12           3
# 64   6243   87.16    3  39   3           3

# %%
retail_df[retail_df['cluster_id']==0]
# Out:
#                           Player       Span  Mat  Inns  NO   Runs    HS  \
# 3        ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189
# 10               TM Dilshan (SL)  1999-2016  330   303  41  10290  161*
# 12        AC Gilchrist (AUS/ICC)  1996-2008  287   279  11   9619   172
# 17             CH Gayle (ICC/WI)  1999-2015  269   264  17   9221   215
# 20     Yuvraj Singh (Asia/INDIA)  2000-2017  304   278  40   8701   150
# 24     V Sehwag (Asia/ICC/INDIA)  1999-2013  251   245   9   8273   219
# 27  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   369  27   8064   124
# 50              BB McCullum (NZ)  2002-2016  260   228  28   6083   166
# 54       Mohammad Hafeez (PAK)  2003-2017  190   190  12   5876  140*  33.01
# 55           Rameez Raja (PAK)  1985-1997  198   197  15   5841  119*  32.09
# 58              CL Hooper (WI)  1987-2003  227   206  43   5761  113*  35.34
# 60         Tamim Iqbal (BDESH)  2007-2017  173   171   4   5743   154  34.38
# 67            A Jadeja (INDIA)  1992-2000  196   179  36   5359   119  37.47
# 69            BRM Taylor (ZIM)  2004-2015  167   166  15   5258  145*  34.82
# 71          ADR Campbell (ZIM)  1992-2003  188   184  14   5185  131*  30.50
# 72             MN Samuels (WI)  2000-2016  187   177  26   5180  133*  34.30
# 73            RS Mahanama (SL)  1986-1999  213   198  23   5162  119*  29.49
# 76        PD Collingwood (ENG)  2001-2011  197   181  37   5092  120*  35.36
# 78     Abdul Razzaq (Asia/PAK)  1996-2011  265   228  57   5080   112  29.70
#
#        BF     SR  100  50   0  cluster_id
# 4   16020  78.96   19  77  28           2
# 14  12669  74.02    7  58   9           2
# 16  11443  81.13   11  64  17           2
# 22  12594  67.72   11  59  13           2
# 26   9721  83.26   21  37  22           2
# 28  11242  71.49    8  49  17           2
# 30   9971  75.91    3  45  15           2
# 31   9571  77.90    4  49  18           2
# 33   9628  75.29    7  48  22           2
# 35   9383  76.41    5  47  19           2
# 36   9760  72.64   16  41  19           2
# 40   9097  74.59    4  55  13           2
# 41   8278  81.72    9  39  13           2
# 43   9723  67.58    6  40  18           2
# 44   8174  80.30   10  37  14           2
# 45   9134  71.42    3  39  11           2
# 47   9801  63.74    5  44   8           2
# 48   8183  75.03   14  34  15           2
# 52   9157  65.13    5  37   6           2
# 53   7336  80.90    2  33  12           2
# 54   7774  75.58   11  32  16           2
# 55   9226  63.31    9  31  15           2
# 58   7517  76.63    7  29   7           2
# 60   7333  78.31    9  38  16           2
# 67   7677  69.80    6  30  10           2
# 69   7060  74.47    8  32  13           2
# 71   7834  66.18    7  30  11           2
# 72   6794  76.24   10  28  10           2
# 73   8521  60.57    4  35  15           2
# 76   6614  76.98    5  26   7           2
# 78   6252  81.25    3  23  14           2

# %%
# plot
sns.boxplot(x='cluster_id', y='Total - Population', data=rfm_df_scaled)

# %%
# plot
sns.boxplot(x='cluster_id', y='Percentage Illiterate', data=rfm_df_scaled)

# %%
# plot
sns.boxplot(x='cluster_id', y='Percentage Graduate & above', data=rfm_df_scaled)

# %% [markdown]
# ## Hierarchical Clustering

# %%
rfm_df_scaled.head()
# Out:
#          SR       Ave
# 0  0.703152  1.072294
# 1 -0.044139  0.587725
# 2  0.110997  0.596226
# 3  1.207091 -1.047909
# 4 -0.034000 -0.876185

# %%
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency  cluster_id
# 0     12346.0     0.00          2      325           2
# 1     12347.0  4310.00        182        1           0
# 2     12348.0  1797.24         31       74           1
# 3     12349.0  1757.55         73       18           1
# 4     12350.0   334.40         17      309           2

# %%
# single linkage
mergings = linkage(rfm_df_scaled, method="single", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# complete linkage
mergings = linkage(rfm_df_scaled, method="complete", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# 3 clusters
cluster_labels = cut_tree(mergings, n_clusters=4).reshape(-1, )
cluster_labels
# Out:
# array([0, 0, 0, 1, 2, 0, 0, 0, 0, 0, 0, 0, 1, 3, 2, 3, 2, 0, 0, 0, 0, 0,
#        0, 0, 1, 3, 0, 1, 2, 0, 2, 2, 0, 2, 3, 2, 2, 0, 3, 0, 2, 2, 0, 2,
#        2, 2, 0, 2, 2, 0, 1, 0, 0, 2, 2, 2, 0, 0, 2, 0, 2, 1, 0, 0, 0, 0,
#        0, 0, 0, 2, 0, 2, 2, 2, 0, 0, 2, 0, 2])

# %%
# assign cluster labels
# retail_df['cluster_labels'] = cluster_labels
retail_df
# Out:
#                           Player       Span  Mat  Inns  NO   Runs    HS  \
# 0           SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*
# 1    KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169
# 2           RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164
# 3        ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189
# 4     DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144
# 5      Inzamam-ul-Haq (Asia/PAK)  1991-2007  378   350  53  11739  137*
# 6         JH Kallis (Afr/ICC/SA)  1996-2014  328   314  53  11579   139
# 7        SC Ganguly (Asia/INDIA)  1992-2007  311   300  23  11363   183
# 8      R Dravid (Asia/ICC/INDIA)  1996-2011  344   318  40  10889   153
# 9               BC Lara (ICC/WI)  1990-2007  299   289  32  10405   169
# 10               TM Dilshan (SL)  1999-2016  330   303  41  10290  161*
# 11    Mohammad Yousuf (Asia/PAK)  1998-2010  288   273  40   9720  141*
# 12        AC Gilchrist (AUS/ICC)  1996-2008  287   279  11   9619   172
# 13         MS Dhoni (Asia/INDIA)  2004-2017  295   255  70   9496  183*
# 14          M Azharuddin (INDIA)  1985-2000  334   308  54   9378  153*
# 15       AB de Villiers (Afr/SA)  2005-2017  222   213  39   9319  162*
# 16              PA de Silva (SL)  1984-2003  308   296  30   9284   145
# 17             CH Gayle (ICC/WI)  1999-2015  269   264  17   9221   215
# 18             Saeed Anwar (PAK)  1989-2003  247   244  19   8824   194
# 19            S Chanderpaul (WI)  1994-2011  268   251  40   8778   150
# 20     Yuvraj Singh (Asia/INDIA)  2000-2017  304   278  40   8701   150
# 21                DL Haynes (WI)  1978-1994  238   237  28   8648  152*
# 22              MS Atapattu (SL)  1990-2007  268   259  32   8529  132*
# 23                ME Waugh (AUS)  1988-2002  244   236  20   8500   173
# 24     V Sehwag (Asia/ICC/INDIA)  1999-2013  251   245   9   8273   219
# 25               V Kohli (INDIA)  2008-2017  188   180  29   8146   183
